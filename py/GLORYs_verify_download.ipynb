# %% [markdown]
# ## Testing Glorys Data
#
# Verify that downloads worked, before proceeding with more of them.

# %%
import xarray as xr
import os
import matplotlib.pyplot as plt
os.chdir("..")

# %%
# Open a file to explore
glorys_93 = xr.open_dataset("GLORYS_data/CMEMS_Northeast_TempSal_1993.nc")
glorys_93
# Out:
# <xarray.Dataset> Size: 562MB
# Dimensions:    (depth: 38, latitude: 132, longitude: 226, time: 31)
# Coordinates:
#   * depth      (depth) float32 152B 0.494 1.541 2.646 ... 1.245e+03 1.452e+03
#   * latitude   (latitude) float32 528B 35.25 35.33 35.42 ... 46.0 46.08 46.17
#   * longitude  (longitude) float32 904B -75.67 -75.58 -75.5 ... -57.0 -56.92
#   * time       (time) datetime64[ns] 248B 1993-01-01 1993-01-02 ... 1993-01-31
# Data variables:
#     thetao     (time, depth, latitude, longitude) float64 281MB ...
#     so         (time, depth, latitude, longitude) float64 281MB ...
# Attributes: (12/25)
#     Conventions:               CF-1.4
#     bulletin_date:             2021-07-07 00:00:00
#     bulletin_type:             operational
#     comment:                   CMEMS product
#     domain_name:               GL12
#     easting:                   longitude
#     ...                        ...
#     references:                http://www.mercator-ocean.fr
# ...

# %%
# Plot a day
glorys_93.isel(time = 0, depth = 0).thetao.plot()

# %%
glorys_93.time.values
# Out:
# array(['1993-01-01T00:00:00.000000000', '1993-01-02T00:00:00.000000000', '1993-01-03T00:00:00.000000000', '1993-01-04T00:00:00.000000000',
#        '1993-01-05T00:00:00.000000000', '1993-01-06T00:00:00.000000000', '1993-01-07T00:00:00.000000000', '1993-01-08T00:00:00.000000000',
#        '1993-01-09T00:00:00.000000000', '1993-01-10T00:00:00.000000000', '1993-01-11T00:00:00.000000000', '1993-01-12T00:00:00.000000000',
#        '1993-01-13T00:00:00.000000000', '1993-01-14T00:00:00.000000000', '1993-01-15T00:00:00.000000000', '1993-01-16T00:00:00.000000000',
#        '1993-01-17T00:00:00.000000000', '1993-01-18T00:00:00.000000000', '1993-01-19T00:00:00.000000000', '1993-01-20T00:00:00.000000000',
#        '1993-01-21T00:00:00.000000000', '1993-01-22T00:00:00.000000000', '1993-01-23T00:00:00.000000000', '1993-01-24T00:00:00.000000000',
#        '1993-01-25T00:00:00.000000000', '1993-01-26T00:00:00.000000000', '1993-01-27T00:00:00.000000000', '1993-01-28T00:00:00.000000000',
# ...
